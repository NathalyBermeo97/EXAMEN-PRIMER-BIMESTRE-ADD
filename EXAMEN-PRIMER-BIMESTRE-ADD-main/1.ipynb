# %%
import couchdb
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

# %%
#APIs
ckey = "ETlntkQqVHA2apjwVNDIjxx6A"
csecret = "JhWwCWUt89HbjVPvGGClcrRoFRMtCGzrMdnMye9TbxujNYDdW2"
atoken = "1339684815814144002-XePfJ1ZQrPte6JwPBNP4Ccj4R9of82"
asecret = "TVz2cmmdZqw3K3gpynCbISMi3ngUKHKo9dKa15ShL02BK"

# %%
server = couchdb.Server("http://Nathaly Bermeo:nathalybermeo@127.0.0.1:5984")
try:
    db = server.create('twitter_couchdb')
except:
    db = server['twitter_couchdb']

# %%
class listener(StreamListener):
    
    def on_data(self, data):
        dictTweet = json.loads(data)
        try:
            
            dictTweet["_id"] = str(dictTweet['id'])
            doc = db.save(dictTweet)
            print ("SAVED" + str(doc) +"=>" + str(data))
        except:
            print ("Already exists")
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())

# %%
#Locations
twitterStream.filter(track=['minecraft'])
# Out:
# SAVED('1351295158759923714', '1-ee4c9feaae7dbc0af4bef0ac29055747')=>{"created_at":"Mon Jan 18 22:27:26 +0000 2021","id":1351295158759923714,"id_str":"1351295158759923714","text":"destroyed a minecraft hacker in my tiktok comments https:\/\/t.co\/u3oqa2X6Tq","display_text_range":[0,50],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1292138261423546373,"id_str":"1292138261423546373","name":"speedsilver alt","screen_name":"speedsilveralt","location":null,"url":null,"description":"@speedsilverr personal account","translator_type":"none","protected":false,"verified":false,"followers_count":1032,"friends_count":1,"listed_count":0,"favourites_count":46,"statuses_count":366,"created_at":"Sat Aug 08 16:39:15 +0000 2020","utc_offset":null,"
# ...
